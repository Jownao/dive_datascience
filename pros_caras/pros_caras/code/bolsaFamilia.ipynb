# %% [markdown]
# # Imports e funções

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt


def convert_sums_frame(sums_object, columns):
    frame_ = pd.data_familiarame(sums_object)
    frame_.reset_index(inplace=True)
    frame_.columns = columns
    return frame_

def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.0f}%\n({:d})".format(pct, absolute)

# %% [markdown]
# ## Analise de familias

# %%
# Dados das famílias
data_familia = pd.read_csv("data_familia_sergipe.csv")
data_bolsa = data_familia.query("marc_pbf == 1")

# %%
dataTemp = data_bolsa.groupby("qtd_comodos_domic_fam")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['qtd_comodos_domic_fam','id_familia'])
dataTemp = dataTemp.sort_values(by='qtd_comodos_domic_fam', ascending=False )

barplot = sns.barplot(data=dataTemp, x="qtd_comodos_domic_fam",y="id_familia")
plt.title('Quartos que pessoas com Bolsa Família possuem em quantidade')
plt.show()
# Out:
# [Text(0, 0, '2'),
#  Text(0, 0, '674'),
#  Text(0, 0, '1458'),
#  Text(0, 0, '2881'),
#  Text(0, 0, '8734'),
#  Text(0, 0, '26065'),
#  Text(0, 0, '6491'),
#  Text(0, 0, '1197'),
#  Text(0, 0, '298'),
#  Text(0, 0, '48'),
#  Text(0, 0, '15'),
#  Text(0, 0, '3'),
#  Text(0, 0, '3'),
#  Text(0, 0, '1'),
#  Text(0, 0, '1')]

# %%
dataTemp = data_familia.groupby("marc_pbf")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['marc_pbf','id_familia'])
dataTemp = dataTemp.sort_values(by='marc_pbf', ascending=False )

barplot = sns.barplot(data=dataTemp, x="marc_pbf",y="id_familia")
plt.title('Familias que possuem ou não Bolsa Família família')
plt.show()
# Out:
# [Text(0, 0, '31708'), Text(0, 0, '50567')]

# %%
dataTemp = data_bolsa.groupby("ind_parc_mds_fam")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['ind_parc_mds_fam','id_familia'])
dataTemp = dataTemp.sort_values(by='ind_parc_mds_fam', ascending=False )

barplot = sns.barplot(data=dataTemp, x="ind_parc_mds_fam",y="id_familia",errwidth=0)
plt.title('Familias com Bolsa Família distribuídas em grupos')
plt.show()
# Out:
# [Text(0, 0, '44616'),
#  Text(0, 0, '34'),
#  Text(0, 0, '7'),
#  Text(0, 0, '863'),
#  Text(0, 0, '9'),
#  Text(0, 0, '49'),
#  Text(0, 0, '3189'),
#  Text(0, 0, '157'),
#  Text(0, 0, '24'),
#  Text(0, 0, '28'),
#  Text(0, 0, '9'),
#  Text(0, 0, '26'),
#  Text(0, 0, '404')]

# %%
dataTemp = data_bolsa.groupby("cod_iluminacao_domic_fam")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_iluminacao_domic_fam','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_iluminacao_domic_fam', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_iluminacao_domic_fam",y="id_familia",errwidth=0)
plt.title('Familias com Bolsa Família e os tipos de iluminação')
plt.show()
# Out:
# [Text(0, 0, '44107'),
#  Text(0, 0, '946'),
#  Text(0, 0, '1201'),
#  Text(0, 0, '184'),
#  Text(0, 0, '196'),
#  Text(0, 0, '1255')]

# %%
dataTemp = data_bolsa.groupby("cod_local_domic_fam")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_local_domic_fam','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_local_domic_fam', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_local_domic_fam",y="id_familia",errwidth=0)
plt.title('Familias com Bolsa Família e suas localidades de morada')
plt.show()
# Out:
# [Text(0, 0, '31618'), Text(0, 0, '18868')]

# %%
dataTemp = data_bolsa.groupby("cod_material_piso_fam")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_material_piso_fam','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_material_piso_fam', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_material_piso_fam",y="id_familia",errwidth=0)
plt.title('Familias com Bolsa Família e material predominante no piso')
plt.show()
# Out:
# [Text(0, 0, '1393'),
#  Text(0, 0, '26096'),
#  Text(0, 0, '55'),
#  Text(0, 0, '48'),
#  Text(0, 0, '20212'),
#  Text(0, 0, '15'),
#  Text(0, 0, '70')]

# %%
dataTemp = data_bolsa.groupby("cod_material_domic_fam")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_material_domic_fam','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_material_domic_fam', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_material_domic_fam",y="id_familia",errwidth=0)
plt.title('Familias com Bolsa Família e materias das paredes externas')
plt.show()
# Out:
# [Text(0, 0, '37044'),
#  Text(0, 0, '9382'),
#  Text(0, 0, '54'),
#  Text(0, 0, '542'),
#  Text(0, 0, '559'),
#  Text(0, 0, '87'),
#  Text(0, 0, '9'),
#  Text(0, 0, '212')]

# %%
dataTemp = data_bolsa.groupby("cod_banheiro_domic_fam")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_banheiro_domic_fam','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_banheiro_domic_fam', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_banheiro_domic_fam",y="id_familia",errwidth=0)
plt.title('Familias com Bolsa Família e existência de banheiro')
plt.show()
# Out:
# [Text(0, 0, '45722'), Text(0, 0, '2167')]

# %% [markdown]
# ## Analises de Pessoas

# %% [markdown]
# #### Pessoas com Bolsa Família

# %%
dataPessoas = pd.read_csv("data_pessoas_sergipe.csv")
dataMerge_PF = pd.merge(data_familia,dataPessoas,on ='id_familia') # Familias e pessoas 
dataMerge_PF_bolsa = pd.merge(data_bolsa,dataPessoas,on ='id_familia') #Familias e pessoas com Bolsa Família
dataMergeRegular = dataMerge_PF.query("vlr_renda_media_fam <= 170") # Famílias e pessoas regulares na Bolsa Família
dataMergeIrregular = dataMerge_PF.query("vlr_renda_media_fam > 170") # Famílias e pessoas irregulares na Bolsa Família

# %%
barplot = sns.histplot(dataMerge_PF_bolsa['vlr_renda_media_fam'])
plt.title('Pessoas com bolsa - Renda média')
# Out:
# Text(0.5, 1.0, 'Pessoas com bolsa x Renda média')

# %%
dataPie = dataMerge_PF_bolsa.groupby("cod_sexo_pessoa")["id_familia"].count()

plt.pie(dataPie)
plt.title('Gênero com Bolsa Família Família')
plt.legend(('Masculino','Feminino'))
plt.show()

# %%
dataTemp = dataMerge_PF_bolsa.groupby("cod_principal_trab_memb")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_principal_trab_memb','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_principal_trab_memb', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_principal_trab_memb",y="id_familia",errwidth=0)
plt.title('Pessoas com Bolsa Família - Funções')
plt.show()
# Out:
# [Text(0, 0, '20542'),
#  Text(0, 0, '13985'),
#  Text(0, 0, '373'),
#  Text(0, 0, '706'),
#  Text(0, 0, '572'),
#  Text(0, 0, '74'),
#  Text(0, 0, '456'),
#  Text(0, 0, '88'),
#  Text(0, 0, '3'),
#  Text(0, 0, '19'),
#  Text(0, 0, '60')]

# %%
dataTemp = dataMerge_PF_bolsa.groupby("cod_agricultura_trab_memb")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_agricultura_trab_memb','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_agricultura_trab_memb', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_agricultura_trab_memb",y="id_familia",errwidth=0)
plt.title('Pessoas com Bolsa Família - Extrativismo')
plt.show()
# Out:
# [Text(0, 0, '16183'), Text(0, 0, '19276')]

# %%
dataTemp = dataMerge_PF_bolsa.groupby("cod_concluiu_frequentou_memb")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_concluiu_frequentou_memb','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_concluiu_frequentou_memb', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_concluiu_frequentou_memb",y="id_familia",errwidth=0)
plt.title('Pessoas com Bolsa Família - Se concluiu curso superior')
plt.show()
# Out:
# [Text(0, 0, '22551'), Text(0, 0, '40155')]

# %%
dataTemp = dataMerge_PF_bolsa.groupby("cod_ano_serie_frequentou_memb")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_ano_serie_frequentou_memb','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_ano_serie_frequentou_memb', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_ano_serie_frequentou_memb",y="id_familia",errwidth=0)
plt.title('Pessoas com Bolsa Família - Último ano frequentado')
plt.show()
# Out:
# [Text(0, 0, '7526'),
#  Text(0, 0, '6843'),
#  Text(0, 0, '17766'),
#  Text(0, 0, '8209'),
#  Text(0, 0, '7736'),
#  Text(0, 0, '4693'),
#  Text(0, 0, '4211'),
#  Text(0, 0, '4995'),
#  Text(0, 0, '504'),
#  Text(0, 0, '222')]

# %%
dataTemp = dataMerge_PF_bolsa.groupby("cod_curso_frequentou_pessoa_memb")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_curso_frequentou_pessoa_memb','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_curso_frequentou_pessoa_memb', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_curso_frequentou_pessoa_memb",y="id_familia",errwidth=0)
plt.title('Pessoas com Bolsa Família - Curso mais alto frequentado')
plt.show()
# Out:
# [Text(0, 0, '8'),
#  Text(0, 0, '32'),
#  Text(0, 0, '279'),
#  Text(0, 0, '19437'),
#  Text(0, 0, '18377'),
#  Text(0, 0, '4805'),
#  Text(0, 0, '311'),
#  Text(0, 0, '19100'),
#  Text(0, 0, '676'),
#  Text(0, 0, '238'),
#  Text(0, 0, '567'),
#  Text(0, 0, '355'),
#  Text(0, 0, '490'),
#  Text(0, 0, '93'),
#  Text(0, 0, '20')]

# %%
dataTemp = dataMerge_PF_bolsa.groupby("cod_ano_serie_frequenta_memb")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_ano_serie_frequenta_memb','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_ano_serie_frequenta_memb', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_ano_serie_frequenta_memb",y="id_familia",errwidth=0)
plt.title('Pessoas com Bolsa Família - Ano/Série Frequentado')
plt.show()
# Out:
# [Text(0, 0, '7630'),
#  Text(0, 0, '5593'),
#  Text(0, 0, '6474'),
#  Text(0, 0, '4851'),
#  Text(0, 0, '4453'),
#  Text(0, 0, '5864'),
#  Text(0, 0, '4149'),
#  Text(0, 0, '3166'),
#  Text(0, 0, '2153'),
#  Text(0, 0, '13')]

# %%
barplot = sns.histplot(dataMerge_PF_bolsa['idade'])
plt.title('Pessoas com Bolsa Família - Idade das Pessoas')
# Out:
# Text(0.5, 1.0, 'Pessoas com bolsa x Idade')

# %%
dataTemp = dataMerge_PF_bolsa.groupby("ind_frequenta_escola_memb")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['ind_frequenta_escola_memb','id_familia'])
dataTemp = dataTemp.sort_values(by='ind_frequenta_escola_memb', ascending=False )

plt.title('Pessoas com Bolsa Família - 1 Rede Pub. / 2 Rede Part. / 3 Já frequentou / 4 Nunca frequentou')
plt.show()
# Out:
# [Text(0, 0, '47597'),
#  Text(0, 0, '4898'),
#  Text(0, 0, '64797'),
#  Text(0, 0, '22333')]

# %%
dataTemp = dataMerge_PF_bolsa.groupby("cod_sabe_ler_escrever_memb")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_sabe_ler_escrever_memb','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_sabe_ler_escrever_memb', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_sabe_ler_escrever_memb",y="id_familia",errwidth=0)
plt.title('Pessoas com Bolsa Família - Sabe ler e escrever')
plt.show()
# Out:
# [Text(0, 0, '99884'), Text(0, 0, '39741')]

# %%
dataTemp = dataMerge_PF_bolsa.groupby("cod_raca_cor_pessoa")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_raca_cor_pessoa','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_raca_cor_pessoa', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_raca_cor_pessoa",y="id_familia",errwidth=0)
plt.title('Pessoas com Bolsa Família - Raça da pessoa')
plt.show()
# Out:
# [Text(0, 0, '17997'),
#  Text(0, 0, '6214'),
#  Text(0, 0, '716'),
#  Text(0, 0, '114516'),
#  Text(0, 0, '188')]

# %%
dataTemp = dataMerge_PF_bolsa.groupby("cod_parentesco_rf_pessoa")['id_familia'].count()
dataTemp = convert_sums_frame(dataTemp, ['cod_parentesco_rf_pessoa','id_familia'])
dataTemp = dataTemp.sort_values(by='cod_parentesco_rf_pessoa', ascending=False )

barplot = sns.barplot(data=dataTemp, x="cod_parentesco_rf_pessoa",y="id_familia",errwidth=0)
plt.title('Pessoas com Bolsa Família - Relação de parentesco com o RF')
plt.show()
# Out:
# [Text(0, 0, '50567'),
#  Text(0, 0, '14140'),
#  Text(0, 0, '69757'),
#  Text(0, 0, '278'),
#  Text(0, 0, '2778'),
#  Text(0, 0, '292'),
#  Text(0, 0, '12'),
#  Text(0, 0, '797'),
#  Text(0, 0, '71'),
#  Text(0, 0, '877'),
#  Text(0, 0, '73')]

# %% [markdown]
# #### Pessoas Irregulares

# %%
barplot = sns.boxplot(dataMergeIrregular['vlr_renda_media_fam'])
plt.title('Pessoas com Bolsa Família Irregular x Renda média')
# Out:
# d:\Arquivos e progamas\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Pessoas com bolsa IRREGULAR x Renda média')

# %%
barplot = sns.boxplot(dataMergeIrregular['val_renda_bruta_12_meses_memb'])
plt.title('Pessoas com Bolsa Família Irregular x Renda bruta 12 meses')
# Out:
# d:\Arquivos e progamas\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Pessoas com bolsa IRREGULAR x Renda bruta 12 meses')

# %% [markdown]
# #### Pessoas Regulares

# %%
barplot = sns.boxplot(dataMergeRegular['vlr_renda_media_fam'])
plt.title('Pessoas com Bolsa Família Regular - Renda média')
# Out:
# d:\Arquivos e progamas\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Pessoas com bolsa REGULAR x Renda média')

# %%
barplot = sns.boxplot(dataMergeRegular['val_renda_bruta_12_meses_memb'])
plt.title('Pessoas com Bolsa Família Regular - Renda bruta dos últimos 12 meses')
# Out:
# d:\Arquivos e progamas\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Pessoas com bolsa REGULAR x Renda bruta 12 meses')
